# %% [markdown]
# <a href="https://colab.research.google.com/github/npr99/URSC645/blob/main/CodingExcercises/ReadSourceData/URSC645_GoogleColab_Read_SourceData_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read in Source Data
# Notebook provides an example of how to read in data from SourceData Folder.
#
# This example uses relative paths to locate the data in Google Colab.
# This requires that the Google Drive is mounted in the Google Colab notebook and that the directory is changed to the indiviudal work folder.

# %% [markdown]
# ## Step 1: Mount Google Drive to Google Colab
# Google Colab can access files that are located within your Google Drive Account.
#
# The following code is required to connect your Google Drive Account to the Google Colab enviroment. Notice that running the next code block will generate several pop-up screens asking for permission to make the connection.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The following alert messages should appear on your screen.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step 2: Locate the local folder where the Google Colab Notebook is saved.

# %%
import os # package needed to change and check directories

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# Notice that the current working directory is called "content". In the Google Colab Enviroment you can click on the folder icon in the left menu to see the content folder. Inside the content folder it is possible to locate your Google Drive Account folders and see your directories.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Step 3: Change the current directory
# Use the OS Change Directory function (os.chdir) to change the current working directory.
#
# Notice that the text string with the current directory needs to have either forward slashes '/' or double backwards slashes '\\' between the directory names.

# %%
os.chdir('/content/drive/MyDrive/MyCourses/URSC645/github_com/npr99/URSC645/CodingExcercises/ReadSourceData')

# %%
# Check to see that the current directory is set correctly
os.getcwd()
# Out:
# '/content/drive/MyDrive/MyCourses/URSC645/github_com/npr99/URSC645/CodingExcercises/ReadSourceData'

# %% [markdown]
# ## Step 4: Read in CSV file using Relative Paths
# Relative paths is a powerful tool to help organize a reproducible data science workflow. Relative paths allow for common source files to be shared within a collabartive team project and for code to be shared without needing to change the local directory.

# %%
import pandas as pd

# %% [markdown]
# Notice the use of the
#
# ```
# '../../'
# ```
#
# The double dots informs the enviroment to move up one directory relative to the current directory. In the example below the SourceData folder is 2 directories above the current directory.
#
# Once the enviroment is informed about the relative location of the folder the folder path to the data can be set.

# %%
dataframe = pd.read_csv('../../SourceData/data.census.gov/ACSDT5Y2018.B09002_2020-03-30T094416/ACSDT5Y2018.B09002_data_with_overlays_2020-03-30T094414.csv')

# %%
dataframe.head()
# Out:
#            GEO_ID  ...                                        B09002_020M
# 0              id  ...  Margin of Error!!Total!!In other families!!Fem...
# 1  0500000US48015  ...                                                233
# 2  0500000US48261  ...                                                  6
# 3  0500000US48355  ...                                                697
# 4  0500000US48089  ...                                                169
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Success!
# The source file has been read into the Google Colab Environment. Notice however that exploring the data using the .head() function reveals that the data will need to be cleaned.

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...
